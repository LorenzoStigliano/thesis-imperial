# %%
times = [0.3746661758422852,
            0.2976107311248779, 
            0.5369727993011475, 
            0.5691804313659667, 
            2.066271357536316, 
            3.095452666282654,
            1.9482540798187256,
            2.259423885345459, 
            2.6304433345794678,
            2.9120749616622925]

rep = [0.88875,
0.940417,
0.928472,
0.702778,
0.773056,
0.805278,
0.944,
0.932,
0.969,
0.978]

acc = [0.661582,
    0.637472,
    0.639818,
    0.642089,
    0.655798,
    0.652761,
    0.6,
    0.602,
    0.619,
    0.614]

# %%
import matplotlib.pyplot as plt

# Sample data
times = [0.3746661758422852, 0.2976107311248779, 0.5369727993011475, 0.5691804313659667, 2.066271357536316, 3.095452666282654, 1.9482540798187256, 2.259423885345459, 2.6304433345794678, 2.9120749616622925]
rep = [0.88875, 0.940417, 0.928472, 0.702778, 0.773056, 0.805278, 0.944, 0.932, 0.969, 0.978]
acc = [0.661582, 0.637472, 0.639818, 0.642089, 0.655798, 0.652761, 0.6, 0.602, 0.619, 0.614]
tags = ["Teacher", "Student", "Vanilla", "FitNet", "LSP", "MSKD", "RepKD 2", "RepKD 3", "RepKD 4", "RepKD 5"]

# Create figure and axes
fig, ax1 = plt.subplots()

# Scatter plot annotations
for i, tag in enumerate(tags):
    ax1.scatter(times[i], rep[i], color='tab:blue')
    ax1.annotate(tag, (times[i], rep[i]), textcoords="offset points", xytext=(5, 10), ha='center', fontsize=8)


# Plot reproducibility
ax1.scatter(times, rep)
ax1.set_xlabel('Time')
ax1.set_ylabel('Reproducibility', color='tab:blue')
ax1.tick_params(axis='y', labelcolor='tab:blue')

# Display the plot
plt.title('Reproducibility over Time')
plt.show()

# %%
import matplotlib.pyplot as plt

# Sample data
times = [0.3746661758422852, 0.2976107311248779, 0.5369727993011475, 0.5691804313659667, 2.066271357536316, 3.095452666282654, 1.9482540798187256, 2.259423885345459, 2.6304433345794678, 2.9120749616622925]
rep = [0.88875, 0.940417, 0.928472, 0.702778, 0.773056, 0.805278, 0.944, 0.932, 0.969, 0.978]
acc = [0.661582, 0.637472, 0.639818, 0.642089, 0.655798, 0.652761, 0.6, 0.602, 0.619, 0.614]
tags = ["Teacher", "Student", "Vanilla", "FitNet", "LSP", "MSKD", "RepKD 2", "RepKD 3", "RepKD 4", "RepKD 5"]

# Create figure and axes
fig, ax1 = plt.subplots()

# Scatter plot annotations
for i, tag in enumerate(tags):
    ax1.scatter(times[i], acc[i], color='tab:blue')
    ax1.annotate(tag, (times[i], acc[i]), textcoords="offset points", xytext=(5, 10), ha='center', fontsize=8)

# Plot reproducibility
ax1.scatter(times, acc)
ax1.set_xlabel('Time')
ax1.set_ylabel('Acccuracy', color='tab:blue')
ax1.tick_params(axis='y', labelcolor='tab:blue')

# Display the plot
plt.title('Accuracy over Time')
plt.show()

# %% [markdown]
# # TRAINABLE PARAMS

# %%
import matplotlib.pyplot as plt

# Sample data
params = [108, 108, 108, 108, 216, 324, 432, 540]
rep = [0.928472, 0.702778, 0.773056, 0.805278, 0.944, 0.932, 0.969, 0.978]
acc = [0.639818, 0.642089, 0.655798, 0.652761, 0.6, 0.602, 0.619, 0.614]
tags = ["Vanilla", "FitNet", "LSP", "MSKD", "RepKD 2", "RepKD 3", "RepKD 4", "RepKD 5"]

# Create figure and axes
fig, ax1 = plt.subplots()

# Scatter plot annotations
for i, tag in enumerate(tags):
    ax1.scatter(params[i], rep[i], color='tab:blue')
    ax1.annotate(tag, (params[i], rep[i]), textcoords="offset points", xytext=(5, 10), ha='center', fontsize=8)


# Plot reproducibility
ax1.scatter(params, rep)
ax1.set_xlabel('Params')
ax1.set_ylabel('Reproducibility', color='tab:blue')
ax1.tick_params(axis='y', labelcolor='tab:blue')

# Display the plot
plt.title('Reproducibility over Time')
plt.show()
